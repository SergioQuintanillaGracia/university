# %% [markdown]
# Hacer fine tunning pero solo entrenando la capa de salida

# %%
for p in model.parameters():
    p.requires_grad = False
for p in model.fc.parameters():
    p.requires_grad = True
exp(model, device, train_loader, test_loader, lr=1e-3, epochs=5)
