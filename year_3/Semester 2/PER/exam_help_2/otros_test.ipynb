# %% [markdown]
# ## PER2526, grupo de laboratorio L1-3CO11
# ## A3. Prueba práctica de laboratorio de B2 (test B) (0,75 puntos)
# ## 26 de mayo de 2026
# ### Puntuación: max(0, (aciertos − errores / 3) · 0,25)

# %% [markdown]
# $\Large\square\;$ Si queremos hacer un finetuning de un modelo `model_name` sobre Cifar-10 usando la librería `timm`, ¿Cuál es la forma correcta de cargar el modelo?
#
# 1. ```python
#     model = timm.create_model(model_name, pretrained=True)
#     ```
#
# 2. ```python
#     model = timm.create_model(model_name, pretrained=False)
#     ```
#
# 3. ```python
#     model = timm.create_model(model_name, pretrained=True, num_classes=10)
#     ```
#
# 4. ```python
#     model = timm.create_model(model_name, pretrained=False, num_classes=10)
#     ```

# %% [markdown]
# Nombre y apellidos:

# %%
3

# %% [markdown]
# $\Large\square\;$ Los schedulers...
#
# 1. Permiten actualizar el learning rate en tiempo de entrenamiento.
#
# 2. Sirven para decidir el valor del learning rate antes de empezar el entrenamiento.
#
# 3. Permiten modificar la arquitectura del modelo en tiempo de entrenamiento.
#
# 4. Ayudan a reducir el tiempo de entrenamiento mediante conocimiento experto de la tarea.

# %%
1

# %% [markdown]
# $\Large\square\;$ Elige la opción incorrecta respecto a las transformaciones de datos...
#
# 1. Permiten girar, rotar y normalizar imágenes, entre otros.
#
# 2. Se aplican en tiempo de entrenamiento.
#
# 3. Son una técnica que combina datos reales con datos sintéticos generados mediante transformaciones razonables.
#
# 4. Se deben aplicar tanto al conjunto de entrenamiento como al de test.

# %%
4

# %% [markdown]
# <p style="page-break-after:always;"></p>
